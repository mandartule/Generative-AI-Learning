# %% [markdown]
# **3.1. Accessing OpenAI LLMs via API in Python**

# %%
# !pip install -q -U openai python-dotenv
# Out:
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI(
    base_url="https://openai.generative.engine.capgemini.com/v1"
)
response = client.chat.completions.create(
    model="openai.gpt-5-nano",
    messages=[
        {"role": "user", "content": "How to be happy tell me in three lines"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Practice daily gratitude and notice the small joys.
# Nurture meaningful connections and perform small acts of kindness.
# Take care of your body and mind: sleep well, move, and reflect.

# %%
response
# Out:
# ChatCompletion(id='d4c7cc7b-5042-4dc4-bbea-f9fc96b08026', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Under a silver moon, a gentle unicorn named Luma wandered through a quiet meadow.  \nShe sprinkled a little starlight from her horn to tuck every sleeping flower and fluttering moth into dreams.  \nThen Luma curled on a bed of moss and listened to the night breathe softly, until dawn promised a new day.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, id='6fd253d5-c647-4620-b3fc-1b5b4a11da3a'))], created=1786603063, model='openai.gpt-5-nano', object='chat.completion', moderation=None, service_tier=None, system_fingerprint='v1.0.0', usage=CompletionUsage(completion_tokens=714, prompt_tokens=16, total_tokens=730, completion_tokens_details=None, prompt_tokens_details=None))

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://openai.generative.engine.capgemini.com/v1"
)

response = client.chat.completions.create(
    model="openai.gpt-5-nano",
    messages=[
        {"role": "user", "content": "Why sky is blue?"}
    ]
)

# print(response)
print(response.choices[0].message.content)
# Out:
# The sky appears blue to us because of a phenomenon called Rayleigh scattering. This occurs when the sunlight passes through the Earth's atmosphere and interacts with the gas molecules and particles in the air. The shorter blue wavelengths of light are scattered more easily by these molecules than the longer wavelengths of red light. This scattering causes the blue light to be dispersed in all directions, giving the sky its blue color.

# %% [markdown]
# **Chat Completion**

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://openai.generative.engine.capgemini.com/v1"
)

completion = client.chat.completions.create(
    model="openai.gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful chat assistant."},
        {"role": "user", "content": "What is Machine Learning?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from openai import OpenAI
#       2
# ----> 3 client = OpenAI(
#       4     base_url="https://openai.generative.engine.capgemini.com/v1"
#       5 )
#       6
#
# File ~\OneDrive - Capgemini\Desktop\Training\Agentic Ai\env\Lib\site-packages\openai\_client.py:231, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     221 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     223 if (
#     224     provider_runtime is None
#     225     and _enforce_credentials
#    (...)    229     and self.admin_api_key is None
#     230 ):
# --> 231     raise OpenAIError(
#     232         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     233     )
#     235 if organization is None and provider_runtime is None:
#     236     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
from openai import OpenAI
client = OpenAI(
    base_url="https://openai.generative.engine.capgemini.com/v1"
)

# maintain chat history in a list
chat_history = [
    {"role": "system", "content": "You are a helpful chat assistant."},
    {"role": "user", "content": "What is Machine Learning?"},
    {"role": "assistant", "content": "Machine Learning is a field of AI where systems learn patterns from data and improve without explicit programming."},
    {"role": "user", "content": "Can you give me some examples?"}
]

# send the full history to the API
completion = client.chat.completions.create(
    model="openai.gpt-5-nano",
    messages=chat_history
)

response = completion.choices[0].message.content
print(response)

# add the assistant's reply back into history for next round
chat_history.append({"role": "assistant", "content": response})
# Out:
# Sure. Here are some common machine learning examples across major approaches:
#
# - Supervised learning (learn from labeled data)
#   - Email spam filtering: classify emails as spam or not spam.
#   - Image classification: identify objects in pictures (e.g., cats vs dogs, recognizing faces).
#   - House price prediction: predict a numeric price based on features like size, location, etc.
#   - Medical diagnosis from data: predict diseases from patient records or imaging (e.g., detecting tumors in scans).
#
# - Unsupervised learning (find patterns in unlabeled data)
#   - Customer segmentation: group customers into similar clusters based on purchasing behavior.
#   - Topic modeling: discover themes in a collection of documents (e.g., news articles).
#   - Anomaly detection: spot unusual network activity or fraud patterns.
#   - Dimensionality reduction: reduce many features to key components for visualization (e.g., PCA).
#
# - Reinforcement learning (learn by interacting with an environment)
#   - Game-playing agents: learn to play games like chess, Go, or Atari games.
#   - Robotics and navigation: teach a robot to move through an environment to reach a goal.
#   - Energy optimization: control cooling or electricity use in a data center for efficiency.
#
# - Semi-supervised and self-supervised learning (leverage limited labels or unlabeled data)
#   - Semi-supervised labeling: improve a model with a small set of labeled examples plus lots of unlabeled data.
#   - Self-supervised language models: learn from raw text by solving tasks like predicting the next word or filling in blanks (basis for models like GPT, BERT).
#
# If you want, tell me your domain of interest (health, finance, marketing, etc.), and I can tailor examples closer to that area.

# %%
chat_history
# Out:
# [{'role': 'system', 'content': 'You are a helpful chat assistant.'},
#  {'role': 'user', 'content': 'What is Machine Learning?'},
#  {'role': 'assistant',
#   'content': 'Machine Learning is a field of AI where systems learn patterns from data and improve without explicit programming.'},
#  {'role': 'user', 'content': 'Can you give me some examples?'},
#  {'role': 'assistant',
#   'content': 'Sure. Here are some common machine learning examples across major approaches:\n\n- Supervised learning (learn from labeled data)\n  - Email spam filtering: classify emails as spam or not spam.\n  - Image classification: identify objects in pictures (e.g., cats vs dogs, recognizing faces).\n  - House price prediction: predict a numeric price based on features like size, location, etc.\n  - Medical diagnosis from data: predict diseases from patient records or imaging (e.g., detecting tumors in scans).\n\n- Unsupervised learning (find patterns in unlabeled data)\n  - Customer segmentation: group customers into similar clusters based on purchasing behavior.\n  - Topic modeling: discover themes in a collection of documents (e.g., news articles).\n  - Anomaly detection: spot unusual network activity or fraud patterns.\n  - Dimensionality reduction: reduce many features to key components for visualization (e.g., PCA).\n\n- Reinforcement learning (learn by interacting with an environment)\n  - Game-playing agents: learn to play games like chess, Go, or Atari games.\n  - Robotics and navigation: teach a robot to move through an environment to reach a goal.\n  - Energy optimization: control cooling or electricity use in a data center for efficiency.\n\n- Semi-supervised and self-supervised learning (leverage limited labels or unlabeled data)\n  - Semi-supervised labeling: improve a model with a small set of labeled examples plus lots of unlabeled data.\n  - Self-supervised language models: learn from raw text by solving tasks like predicting the next word or filling in blanks (basis for models like GPT, BERT).\n\nIf you want, tell me your domain of interest (health, finance, marketing, etc.), and I can tailor examples closer to that area.'}]
